# %%
from Context import Context

context = Context(name='test')

# %%
from scipy import stats

context.create_quantity(name='testq', pdf=stats.gamma.pdf, cdf=stats.gamma.cdf, sample=stats.gamma.rvs, 
                        kwargs={'a': 10, 'scale': 2000}, domain_type='continuous')

# %%
context.quantities['testq'].pdf(1000)
# Out:
# np.float64(1.6322616219566203e-12)

# %%
context.visualize_quantity(context.quantities['testq'].cdf, context.quantities['testq'])
